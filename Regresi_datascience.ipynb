# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('test103.csv', usecols=['Age', 'Spending_Score'])

# %%
df.head()
# Out:
#    Age  Spending_Score
# 0   36               1
# 1   37               3
# 2   69               3
# 3   59               5
# 4   19               1

# %%
df.shape
# Out:
# (86, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             86 non-null     int64
#  1   Spending_Score  86 non-null     int64
# dtypes: int64(2)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#              Age  Spending_Score
# count  86.000000       86.000000
# mean   48.779070        2.674419
# std    20.346065        1.676424
# min    18.000000        1.000000
# 25%    32.750000        1.000000
# 50%    47.000000        3.000000
# 75%    67.750000        5.000000
# max    88.000000        5.000000

# %%
df.isnull().sum()
# Out:
# Age               0
# Spending_Score    0
# dtype: int64

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['Age'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['Age'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['Spending_Score'].plot(kind='kde', c='g')

f.add_subplot(1,2,2)
plt.boxplot(df['Spending_Score'])
plt.show()

# %%
plt.scatter(df['Age'], df['Spending_Score'])
plt.xlabel('Age')
plt.ylabel('Spending_Score')
plt.title('Scatter Plot Age vs Spending_Score')
plt.show()

# %%
df.corr()
# Out:
#                      Age  Spending_Score
# Age             1.000000        0.826361
# Spending_Score  0.826361        1.000000

# %%
df.head()
# Out:
#    Age  Spending_Score
# 0   36               1
# 1   37               3
# 2   69               3
# 3   59               5
# 4   19               1

# %%
x = df['Age'].values.reshape(-1,1)
y = df['Spending_Score'].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [[0.06526982]]
# [-0.55849749]

# %%
lin_reg.score(x_test, y_test)
# Out:
# 0.6994158377245624

# %%
y_prediksi = lin_reg.predict(x_test)
plt.scatter(x_test, y_test)
plt.plot(x_test, y_prediksi, c='r')
plt.xlabel('Age')
plt.ylabel('Spending_Score')
plt.title('Plot Age vs Spending_Score')
# Out:
# Text(0.5, 1.0, 'Plot Age vs Spending_Score')

# %%
#Prediksi umur rata-rata customer dengan spending score 30
lin_reg.predict([[30]])
# Out:
# array([[1.39959707]])

# %%
#Prediksi umur rata-rata customer dengan spending score 60
lin_reg.predict([[60]])
# Out:
# array([[3.35769162]])

# %%
#Prediksi umur rata-rata customer dengan spending score 80
lin_reg.predict([[80]])
# Out:
# array([[4.66308799]])
